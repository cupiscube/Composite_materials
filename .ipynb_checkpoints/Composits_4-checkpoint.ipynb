# %% [markdown]
# # Imports

# %%
import pandas as pd
import numpy as np
import scipy
import math

# sklearn
# from sklearn.model_selection import train_test_split
# from sklearn.model_selection import StratifiedKFold
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import accuracy_score
from sklearn.metrics import mean_squared_error, mean_absolute_error

# deep learning
from tensorflow.keras import Sequential
from tensorflow.keras.layers import Dense

from matplotlib import pyplot as plt
import seaborn as sns

# %matplotlib inline
# Out:
# WARNING:tensorflow:From C:\Users\Danil\PycharmProjects\GITHUB\Composite_materials\venv\lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.

# %%
from sklearn.cluster import KMeans
from sklearn.manifold import TSNE

# %% [markdown]
# ## Import DATA
# Примечание: обосновать почему из датасета убираем первые 22 строчки из ноубука 2

# %%
df1 = pd.DataFrame(pd.read_excel('./data/X_bp.xlsx', index_col=0))
df2 = pd.DataFrame(pd.read_excel('./data/X_nup.xlsx', index_col=0))
df = pd.concat([df1, df2], join='inner', axis=1)
df = df[23:]
df
# Out:
#       Соотношение матрица-наполнитель  Плотность, кг/м3  \
# 23                           2.587348       1953.274926
# 24                           2.499918       1942.595777
# 25                           2.046471       2037.631811
# 26                           1.856476       2018.220332
# 27                           3.305535       1917.907506
# ...                               ...               ...
# 1018                         2.271346       1952.087902
# 1019                         3.444022       2050.089171
# 1020                         3.280604       1972.372865
# 1021                         3.705351       2066.799773
# 1022                         3.808020       1890.413468
#
#       модуль упругости, ГПа  Количество отвердителя, м.%  \
# 23              1136.596135                   137.627420
# 24               901.519947                   146.252208
# 25               707.570887                   101.617251
# 26               836.294382                   135.401697
# 27               478.286247                   105.786930
# ...                     ...                          ...
# 1018             912.855545                    86.992183
# 1019             444.732634                   145.981978
# 1020             416.836524                   110.533477
# 1021             741.475517                   141.397963
# 1022             417.316232                   129.183416
#
#       Содержание эпоксидных групп,%_2  Температура вспышки, С_2  \
# 23                          22.344534                234.716883
# 24                          23.081757                351.231874
# 25                          23.146393                312.307205
# 26                          26.435515                327.510377
# 27                          17.874100                328.154579
# ...                               ...                       ...
# 1018                        20.123249                324.774576
# 1019                        19.599769                254.215401
# 1020                        23.957502                248.423047
# 1021                        19.246945                275.779840
# 1022                        27.474763                300.952708
#
#       Поверхностная плотность, г/м2  Модуль упругости при растяжении, ГПа  \
# 23                       555.893453                             80.803222
# 24                       864.725484                             76.178075
# 25                       547.601219                             73.817067
# 26                       150.961449                             77.210762
# 27                       526.692159                             72.345709
# ...                             ...                                   ...
# 1018                     209.198700                             73.090961
# 1019                     350.660830                             72.920827
# 1020                     740.142791                             74.734344
# 1021                     641.468152                             74.042708
# 1022                     758.747882                             74.309704
#
#       Прочность при растяжении, МПа  Потребление смолы, г/м2  \
# 23                      2587.342983               246.613117
# 24                      3705.672523               226.222760
# 25                      2624.026407               178.198556
# 26                      2473.187195               123.344561
# 27                      3059.032991               275.575880
# ...                             ...                      ...
# 1018                    2387.292495               125.007669
# 1019                    2360.392784               117.730099
# 1020                    2662.906040               236.606764
# 1021                    2071.715856               197.126067
# 1022                    2856.328932               194.754342
#
#       Угол нашивки, град  Шаг нашивки  Плотность нашивки
# 23                    90     4.000000          70.000000
# 24                    90     5.000000          47.000000
# 25                    90     5.000000          57.000000
# 26                    90     5.000000          60.000000
# 27                    90     5.000000          70.000000
# ...                  ...          ...                ...
# 1018                  90     9.076380          47.019770
# 1019                  90    10.565614          53.750790
# 1020                  90     4.161154          67.629684
# 1021                  90     6.313201          58.261074
# 1022                  90     6.078902          77.434468
#
# [1000 rows x 13 columns]

# %%
# Переведем некоторые шкалы к одной системе исчисления МПа
df['модуль упругости, МПа'] = df['модуль упругости, ГПа'] / 1000
df['Модуль упругости при растяжении, МПа'] = df['Модуль упругости при растяжении, ГПа'] / 1000

# %%
# Удалим старые данные
df = df.drop(['модуль упругости, ГПа', 'Модуль упругости при растяжении, ГПа'], axis=1)

# %%
df.corr()
# Out:
#                                       Соотношение матрица-наполнитель  \
# Соотношение матрица-наполнитель                              1.000000
# Плотность, кг/м3                                             0.011033
# Количество отвердителя, м.%                                 -0.017575
# Содержание эпоксидных групп,%_2                              0.027885
# Температура вспышки, С_2                                    -0.011712
# Поверхностная плотность, г/м2                               -0.011906
# Прочность при растяжении, МПа                                0.036288
# Потребление смолы, г/м2                                      0.078841
# Угол нашивки, град                                          -0.031401
# Шаг нашивки                                                  0.028404
# Плотность нашивки                                           -0.005432
# модуль упругости, МПа                                        0.032246
# Модуль упругости при растяжении, МПа                        -0.017502
#
#                                       Плотность, кг/м3  \
# Соотношение матрица-наполнитель               0.011033
# Плотность, кг/м3                              1.000000
# Количество отвердителя, м.%                  -0.032137
# Содержание эпоксидных групп,%_2              -0.011680
# Температура вспышки, С_2                     -0.018260
# Поверхностная плотность, г/м2                 0.038236
# Прочность при растяжении, МПа                -0.074165
# Потребление смолы, г/м2                      -0.027946
# Угол нашивки, град                           -0.065604
# Шаг нашивки                                  -0.057841
# Плотность нашивки                             0.082868
# модуль упругости, МПа                        -0.017544
# Модуль упругости при растяжении, МПа         -0.020699
#
#                                       Количество отвердителя, м.%  \
# Соотношение матрица-наполнитель                         -0.017575
# Плотность, кг/м3                                        -0.032137
# Количество отвердителя, м.%                              1.000000
# Содержание эпоксидных групп,%_2                          0.013484
# Температура вспышки, С_2                                 0.081562
# Поверхностная плотность, г/м2                            0.048636
# Прочность при растяжении, МПа                           -0.066785
# Потребление смолы, г/м2                                  0.008184
# Угол нашивки, град                                       0.040215
# Шаг нашивки                                              0.002655
# Плотность нашивки                                        0.019772
# модуль упругости, МПа                                    0.023490
# Модуль упругости при растяжении, МПа                    -0.076936
#
#                                       Содержание эпоксидных групп,%_2  \
# Соотношение матрица-наполнитель                              0.027885
# Плотность, кг/м3                                            -0.011680
# Количество отвердителя, м.%                                  0.013484
# Содержание эпоксидных групп,%_2                              1.000000
# Температура вспышки, С_2                                    -0.008072
# Поверхностная плотность, г/м2                               -0.007685
# Прочность при растяжении, МПа                               -0.031613
# Потребление смолы, г/м2                                      0.015057
# Угол нашивки, град                                           0.008400
# Шаг нашивки                                                  0.012065
# Плотность нашивки                                           -0.044336
# модуль упругости, МПа                                       -0.006186
# Модуль упругости при растяжении, МПа                         0.064757
#
#                                       Температура вспышки, С_2  \
# Соотношение матрица-наполнитель                      -0.011712
# Плотность, кг/м3                                     -0.018260
# Количество отвердителя, м.%                           0.081562
# Содержание эпоксидных групп,%_2                      -0.008072
# Температура вспышки, С_2                              1.000000
# Поверхностная плотность, г/м2                         0.015638
# Прочность при растяжении, МПа                        -0.026122
# Потребление смолы, г/м2                               0.061615
# Угол нашивки, град                                    0.020632
# Шаг нашивки                                           0.018349
# Плотность нашивки                                     0.011071
# модуль упругости, МПа                                 0.031181
# Модуль упругости при растяжении, МПа                  0.023145
#
#                                       Поверхностная плотность, г/м2  \
# Соотношение матрица-наполнитель                           -0.011906
# Плотность, кг/м3                                           0.038236
# Количество отвердителя, м.%                                0.048636
# Содержание эпоксидных групп,%_2                           -0.007685
# Температура вспышки, С_2                                   0.015638
# Поверхностная плотность, г/м2                              1.000000
# Прочность при растяжении, МПа                              0.013333
# Потребление смолы, г/м2                                    0.001071
# Угол нашивки, град                                         0.048971
# Шаг нашивки                                                0.041928
# Плотность нашивки                                         -0.040858
# модуль упругости, МПа                                     -0.017841
# Модуль упругости при растяжении, МПа                       0.014983
#
#                                       Прочность при растяжении, МПа  \
# Соотношение матрица-наполнитель                            0.036288
# Плотность, кг/м3                                          -0.074165
# Количество отвердителя, м.%                               -0.066785
# Содержание эпоксидных групп,%_2                           -0.031613
# Температура вспышки, С_2                                  -0.026122
# Поверхностная плотность, г/м2                              0.013333
# Прочность при растяжении, МПа                              1.000000
# Потребление смолы, г/м2                                    0.026477
# Угол нашивки, град                                         0.025412
# Шаг нашивки                                               -0.056045
# Плотность нашивки                                          0.014987
# модуль упругости, МПа                                      0.048217
# Модуль упругости при растяжении, МПа                       0.011490
#
#                                       Потребление смолы, г/м2  \
# Соотношение матрица-наполнитель                      0.078841
# Плотность, кг/м3                                    -0.027946
# Количество отвердителя, м.%                          0.008184
# Содержание эпоксидных групп,%_2                      0.015057
# Температура вспышки, С_2                             0.061615
# Поверхностная плотность, г/м2                        0.001071
# Прочность при растяжении, МПа                        0.026477
# Потребление смолы, г/м2                              1.000000
# Угол нашивки, град                                  -0.017891
# Шаг нашивки                                          0.021919
# Плотность нашивки                                    0.020064
# модуль упругости, МПа                               -0.007369
# Модуль упругости при растяжении, МПа                 0.045590
#
#                                       Угол нашивки, град  Шаг нашивки  \
# Соотношение матрица-наполнитель                -0.031401     0.028404
# Плотность, кг/м3                               -0.065604    -0.057841
# Количество отвердителя, м.%                     0.040215     0.002655
# Содержание эпоксидных групп,%_2                 0.008400     0.012065
# Температура вспышки, С_2                        0.020632     0.018349
# Поверхностная плотность, г/м2                   0.048971     0.041928
# Прочность при растяжении, МПа                   0.025412    -0.056045
# Потребление смолы, г/м2                        -0.017891     0.021919
# Угол нашивки, град                              1.000000     0.026812
# Шаг нашивки                                     0.026812     1.000000
# Плотность нашивки                               0.109809    -0.008793
# модуль упругости, МПа                          -0.020399    -0.007003
# Модуль упругости при растяжении, МПа            0.020558    -0.031345
#
#                                       Плотность нашивки  \
# Соотношение матрица-наполнитель               -0.005432
# Плотность, кг/м3                               0.082868
# Количество отвердителя, м.%                    0.019772
# Содержание эпоксидных групп,%_2               -0.044336
# Температура вспышки, С_2                       0.011071
# Поверхностная плотность, г/м2                 -0.040858
# Прочность при растяжении, МПа                  0.014987
# Потребление смолы, г/м2                        0.020064
# Угол нашивки, град                             0.109809
# Шаг нашивки                                   -0.008793
# Плотность нашивки                              1.000000
# модуль упругости, МПа                          0.062844
# Модуль упругости при растяжении, МПа           0.014858
#
#                                       модуль упругости, МПа  \
# Соотношение матрица-наполнитель                    0.032246
# Плотность, кг/м3                                  -0.017544
# Количество отвердителя, м.%                        0.023490
# Содержание эпоксидных групп,%_2                   -0.006186
# Температура вспышки, С_2                           0.031181
# Поверхностная плотность, г/м2                     -0.017841
# Прочность при растяжении, МПа                      0.048217
# Потребление смолы, г/м2                           -0.007369
# Угол нашивки, град                                -0.020399
# Шаг нашивки                                       -0.007003
# Плотность нашивки                                  0.062844
# модуль упругости, МПа                              1.000000
# Модуль упругости при растяжении, МПа               0.014482
#
#                                       Модуль упругости при растяжении, МПа
# Соотношение матрица-наполнитель                                  -0.017502
# Плотность, кг/м3                                                 -0.020699
# Количество отвердителя, м.%                                      -0.076936
# Содержание эпоксидных групп,%_2                                   0.064757
# Температура вспышки, С_2                                          0.023145
# Поверхностная плотность, г/м2                                     0.014983
# Прочность при растяжении, МПа                                     0.011490
# Потребление смолы, г/м2                                           0.045590
# Угол нашивки, град                                                0.020558
# Шаг нашивки                                                      -0.031345
# Плотность нашивки                                                 0.014858
# модуль упругости, МПа                                             0.014482
# Модуль упругости при растяжении, МПа                              1.000000

# %% [markdown]
# # Разобьем данные на кластеры

# %% [markdown]
# ## Подбор оптимального количества кластеров

# %% [markdown]
# ### Метод локтя для подбора оптимального количества кластеров

# %%
distortions = []
for i in range(1, 30):
    kmeans = KMeans(
        n_clusters=i, # На сколько кластеров поделить наш ДС
        init='random', # Начальная инициализация центров кластеров
        n_init=10, # Начальное колиечтво этих точек (центров класстеров)
        max_iter=300, # 
        tol=1e-04 # Величина изменения при сдвиге
    )
    kmeans_prediction = kmeans.fit_predict(df)
    # plt.title(f"Clasterisations result with {i} clusters")
    # Draw our points
    # plt.scatter(df[:, 0], df[:, 1], c=kmeans_prediction)
    # Draw our clusters centers
    # plt.scatter(*kmeans.cluster_centers_.T, # Вызываем наши центыр и транспонируем нашу матрицу
    #             marker='*', 
    #             s=200, 
    #             color='r')
    # plt.show()
    distortions.append(kmeans.inertia_)

# %%
plt.plot(range(1,30), distortions, marker='o')
plt.xlabel('Number of clusters')
plt.ylabel('Разброс')
plt.show()

# %% [markdown]
# Оптимальным, с виду, колличеством класстеров является 15

# %% [markdown]
# ### Для визуализации адекватности разбития данных будем использовать TSNE

# %%
tsne_clusters_number = TSNE(n_components=2, init='random').fit_transform(df)
tsne_clusters_number
# Out:
# array([[  0.46694785,  -8.710088  ],
#        [ 22.2131    , -36.198368  ],
#        [  2.694236  ,  -9.961375  ],
#        ...,
#        [ -3.7203207 , -16.848442  ],
#        [-22.072966  ,   7.965968  ],
#        [  0.20677872, -23.338255  ]], dtype=float32)

# %% [markdown]
# ### На основании вышеполученной информации, попроубем разбить данные на 8 класстеров

# %%
kmeans = KMeans(
    n_clusters=8, # На сколько кластеров поделить наш ДС
    init='random', # Начальная инициализация центров кластеров
    n_init=10, # Начальное колиечтво этих точек (центров класстеров)
    max_iter=300, # 
    tol=1e-04 # Величина изменения при сдвиге
)
kmeans_prediction = kmeans.fit_predict(df)

# %%
# Смотрим распределение данных по кластерам
sns.histplot(data = {"Kmeans_classters": kmeans_prediction}, 
             kde=True)
plt.show()

# %%
fig = plt.figure(figsize=(30, 15))
ax = fig.add_subplot()
ax.scatter(tsne_clusters_number[:, 0], tsne_clusters_number[:, 1], c=kmeans.labels_, marker='o', cmap='rainbow')
# ax.set_title("%s: (%.2g sec)" % (label, t1 - t0))
ax.axis('tight')
plt.show()

# %% [markdown]
# ### На основании вышеполученной информации, попроубем разбить данные на 9 класстеров

# %%
kmeans = KMeans(
    n_clusters=9, # На сколько кластеров поделить наш ДС
    init='random', # Начальная инициализация центров кластеров
    n_init=10, # Начальное колиечтво этих точек (центров класстеров)
    max_iter=300, # 
    tol=1e-04 # Величина изменения при сдвиге
)
kmeans_prediction = kmeans.fit_predict(df)

# %%
# Смотрим распределение данных по кластерам
sns.histplot(data = {"Kmeans_classters": kmeans_prediction}, 
             kde=True)
plt.show()

# %%
fig = plt.figure(figsize=(30, 15))
ax = fig.add_subplot()
ax.scatter(tsne_clusters_number[:, 0], tsne_clusters_number[:, 1], c=kmeans.labels_, marker='o', cmap='rainbow')
# ax.set_title("%s: (%.2g sec)" % (label, t1 - t0))
ax.axis('tight')
plt.show()

# %% [markdown]
# Как мы видим один из кластеров пустой, имеет смысл разбить на 8

# %% [markdown]
# ### На основании вышеполученной информации, попроубем разбить данные на 10 класстеров

# %%
kmeans = KMeans(
    n_clusters=15, # На сколько кластеров поделить наш ДС
    init='random', # Начальная инициализация центров кластеров
    n_init=10, # Начальное колиечтво этих точек (центров класстеров)
    max_iter=300, # 
    tol=1e-04 # Величина изменения при сдвиге
)
kmeans_prediction = kmeans.fit_predict(df)

# %%
# Смотрим распределение данных по кластерам
sns.histplot(data = {"Kmeans_classters": kmeans_prediction}, 
             kde=True)
plt.show()

# %%
fig = plt.figure(figsize=(30, 15))
ax = fig.add_subplot()
ax.scatter(tsne_clusters_number[:, 0], tsne_clusters_number[:, 1], c=kmeans.labels_, marker='o', cmap='rainbow')
# ax.set_title("%s: (%.2g sec)" % (label, t1 - t0))
ax.axis('tight')
plt.show()

# %% [markdown]
# ### На основании вышеполученной информации, попроубем разбить данные на 11 класстеров

# %%
kmeans = KMeans(
    n_clusters=11, # На сколько кластеров поделить наш ДС
    init='random', # Начальная инициализация центров кластеров
    n_init=10, # Начальное колиечтво этих точек (центров класстеров)
    max_iter=300, # 
    tol=1e-04 # Величина изменения при сдвиге
)
kmeans_prediction = kmeans.fit_predict(df)

# %%
# Смотрим распределение данных по кластерам
sns.histplot(data = {"Kmeans_classters": kmeans_prediction}, 
             kde=True)
plt.show()

# %%
fig = plt.figure(figsize=(30, 15))
ax = fig.add_subplot()
ax.scatter(tsne_clusters_number[:, 0], tsne_clusters_number[:, 1], c=kmeans.labels_, marker='o', cmap='rainbow')
# ax.set_title("%s: (%.2g sec)" % (label, t1 - t0))
ax.axis('tight')
plt.show()

# %% [markdown]
# ### На основании вышеполученной информации, попроубем разбить данные на 12 класстеров

# %%
kmeans = KMeans(
    n_clusters=15, # На сколько кластеров поделить наш ДС
    init='random', # Начальная инициализация центров кластеров
    n_init=10, # Начальное колиечтво этих точек (центров класстеров)
    max_iter=300, # 
    tol=1e-04 # Величина изменения при сдвиге
)
kmeans_prediction = kmeans.fit_predict(df)

# %%
# Смотрим распределение данных по кластерам
sns.histplot(data = {"Kmeans_classters": kmeans_prediction}, 
             kde=True)
plt.show()

# %%
fig = plt.figure(figsize=(30, 15))
ax = fig.add_subplot()
ax.scatter(tsne_clusters_number[:, 0], tsne_clusters_number[:, 1], c=kmeans.labels_, marker='o', cmap='rainbow')
# ax.set_title("%s: (%.2g sec)" % (label, t1 - t0))
ax.axis('tight')
plt.show()

# %% [markdown]
# ### На основании вышеполученной информации, попроубем разбить данные на 13 класстеров

# %%
kmeans = KMeans(
    n_clusters=13, # На сколько кластеров поделить наш ДС
    init='random', # Начальная инициализация центров кластеров
    n_init=10, # Начальное колиечтво этих точек (центров класстеров)
    max_iter=300, # 
    tol=1e-04 # Величина изменения при сдвиге
)
kmeans_prediction = kmeans.fit_predict(df)

# %%
# Смотрим распределение данных по кластерам
sns.histplot(data = {"Kmeans_classters": kmeans_prediction}, 
             kde=True)
plt.show()

# %%
fig = plt.figure(figsize=(30, 15))
ax = fig.add_subplot()
ax.scatter(tsne_clusters_number[:, 0], tsne_clusters_number[:, 1], c=kmeans.labels_, marker='o', cmap='rainbow')
# ax.set_title("%s: (%.2g sec)" % (label, t1 - t0))
ax.axis('tight')
plt.show()

# %% [markdown]
# ### На основании вышеполученной информации, попроубем разбить данные на 14 класстеров

# %%
kmeans = KMeans(
    n_clusters=14, # На сколько кластеров поделить наш ДС
    init='random', # Начальная инициализация центров кластеров
    n_init=10, # Начальное колиечтво этих точек (центров класстеров)
    max_iter=300, # 
    tol=1e-04 # Величина изменения при сдвиге
)
kmeans_prediction = kmeans.fit_predict(df)

# %%
# Смотрим распределение данных по кластерам
sns.histplot(data = {"Kmeans_classters": kmeans_prediction}, 
             kde=True)
plt.show()

# %%
fig = plt.figure(figsize=(30, 15))
ax = fig.add_subplot()
ax.scatter(tsne_clusters_number[:, 0], tsne_clusters_number[:, 1], c=kmeans.labels_, marker='o', cmap='rainbow')
# ax.set_title("%s: (%.2g sec)" % (label, t1 - t0))
ax.axis('tight')
plt.show()

# %% [markdown]
# ### На основании вышеполученной информации, попроубем разбить данные на 15 класстеров

# %%
kmeans = KMeans(
    n_clusters=15, # На сколько кластеров поделить наш ДС
    init='random', # Начальная инициализация центров кластеров
    n_init=10, # Начальное колиечтво этих точек (центров класстеров)
    max_iter=300, # 
    tol=1e-04 # Величина изменения при сдвиге
)
kmeans_prediction = kmeans.fit_predict(df)
kmeans_prediction
# Out:
# array([ 1, 11,  1,  4,  8,  9,  1,  2,  0,  4,  2,  8,  8, 14,  6,  3,  1,
#         1, 12, 13,  9,  2,  7, 11,  4,  4, 10, 14, 13,  2,  1,  4,  3,  3,
#        12,  1, 13,  2,  3, 12,  2,  8,  7,  2, 12,  5, 13,  7,  0, 10,  8,
#        14,  3,  1,  6,  4, 13, 14, 12, 14,  8,  6,  3,  4,  5, 10, 10, 10,
#         1,  2, 13,  7, 12, 14,  8,  5,  5,  3,  9,  2,  2,  4,  4, 11,  2,
#         5, 12,  4,  4,  2,  6,  0,  9, 12,  3, 13, 14, 13,  9, 10,  4,  4,
#        13, 10, 10, 12,  4, 14,  0,  2,  1,  4,  4, 14, 10,  2,  4,  2,  2,
#        13,  2, 14, 13, 10,  1,  5, 13,  9,  1, 13,  6,  7,  6,  6,  1,  2,
#         4, 13, 10,  9,  9,  1, 14,  4,  1,  3, 12,  1,  9, 11, 12,  3,  7,
#        12, 12, 14,  8,  7,  3, 14,  8,  2, 11,  9, 10,  8,  8,  2,  3,  2,
#         8, 13, 13,  4, 12,  3,  0,  4,  5,  0, 13, 12, 13,  6,  4,  8,  8,
#         2,  2,  1,  4, 13,  2, 10,  2,  2, 12,  0, 10,  8,  0, 14,  2, 12,
#         6,  3,  1,  6,  9,  1,  9,  8, 10,  4, 13,  9,  2,  4,  8,  9,  1,
#        14,  4,  2,  9, 14,  8, 12,  3,  4,  1,  0,  4,  6,  8,  5,  6, 11,
#        12,  7, 10, 14, 12,  8,  1, 13,  4,  7, 13,  9, 10,  0, 13,  5, 12,
#         2,  0,  2,  0,  8, 12, 14,  7,  0,  2,  2,  7,  9,  3,  9,  1, 13,
#         4, 14, 12,  1,  4, 14,  0,  3,  4,  8,  3,  9, 14, 14,  3,  0,  0,
#        13, 14,  0,  4,  0,  1,  6, 10,  3, 10,  3,  9, 14,  0,  5, 10, 10,
#         4,  2,  9,  0,  0,  8,  5,  9, 13,  4,  4, 12,  7,  1, 13,  1,  8,
#        10,  3,  3,  9, 12, 12,  1,  1,  2,  1,  1,  9, 14, 14, 13,  4,  9,
#        13,  8, 12,  1, 12,  9, 10,  5, 13,  5,  3,  4,  6, 10,  6,  0, 14,
#         4,  3, 10, 14, 12,  6, 12, 11,  5, 10, 13,  4,  0,  7,  2,  5,  8,
#         2,  4,  0, 12, 10,  3,  1, 12,  9, 13,  2,  9, 10,  2,  4,  6,  8,
#        13, 12, 14,  1, 14,  1, 14, 14,  1,  0,  8, 13, 10, 12,  5, 13, 13,
#         7, 13,  1, 14,  6,  3,  9,  3, 13, 14, 12,  3,  3, 13, 14,  4,  9,
#         9,  0,  5,  5,  9, 14,  2,  3,  1,  3,  3, 12, 10,  9,  8, 12,  7,
#         3, 13,  9,  1,  8,  0,  3, 10, 13,  4,  0,  4, 14, 14, 11,  1,  4,
#        13,  1, 13,  9,  2,  4,  2,  5,  2,  3,  4,  2,  4, 10,  2,  4, 12,
#        12,  2, 13, 14, 13, 13, 13,  3,  0,  1, 13,  3, 13,  8,  2,  9,  4,
#        11, 12,  3,  8,  1, 14, 13,  5,  4,  3,  4, 12,  7, 12,  1, 13, 13,
#         5,  2,  5, 11,  3,  2,  9, 13, 14,  1, 10,  0,  4, 10,  0,  1, 12,
#         8,  1,  1,  8,  3,  4, 14,  9,  1,  4,  3,  2, 12,  3,  0, 10,  2,
#         2,  6,  2, 12,  3,  8, 13,  9,  7, 11,  1,  6, 14, 13,  2,  2,  1,
#        14,  6, 11,  2,  1,  5, 14,  4,  3,  3,  8, 10,  4,  6,  6,  8, 14,
#         2,  2,  3,  7,  8,  2, 12,  9, 13, 12,  8, 11,  8,  2, 13,  1, 14,
#        12,  0,  3, 10,  2, 13, 10, 12,  3,  3,  2,  2, 12,  7,  1, 13,  1,
#        10,  6,  4,  3,  9,  8,  6,  9,  7,  7,  3,  1,  1, 12,  3,  1,  8,
#         4,  5,  5,  0, 14, 10,  4,  6,  2, 10,  8, 10,  2,  3,  8,  8,  2,
#         4, 10,  2,  7,  4, 14,  2, 13,  6,  0,  3,  3,  2, 14, 11,  8,  4,
#        13,  2, 13,  2, 14, 13, 11, 12, 13,  5,  7,  0,  4,  3, 13, 14,  0,
#         3,  4,  3,  7,  3,  2, 12,  1, 14,  9, 12, 12, 12,  1,  4,  0,  7,
#         0,  1,  4,  4, 11,  3,  2,  2,  3,  9,  1,  2,  1,  2,  6,  4,  0,
#        10,  3,  9,  8,  2,  8,  2,  1,  4,  4,  1,  2, 11,  3, 11,  9,  9,
#         4,  2, 12, 10, 13, 10,  2,  9, 14,  9,  4, 14,  0,  8,  0, 13,  8,
#        12,  2,  6, 13,  8, 14, 12,  3,  2, 10,  3,  9,  7, 12,  1,  9, 13,
#         4, 13,  9,  2,  3,  8, 11,  1, 11,  4,  1, 14,  6,  3, 10,  1,  2,
#        13, 11, 11,  8,  1,  1,  0,  4,  3,  4, 14,  2, 11, 14,  3, 14, 10,
#        10,  2,  9,  8, 13, 10,  9,  3, 12,  1,  2,  3,  0, 13,  3,  3,  1,
#        14, 12, 14,  4, 10,  2, 12,  4, 10,  0, 12,  3, 12, 13,  4,  4,  3,
#         6,  2,  7,  2,  9, 12,  3, 10,  2, 13, 14,  8,  3,  5,  3,  4,  4,
#        13, 11,  4,  9,  2,  6, 14, 11, 13,  3,  1,  4,  9, 12,  1,  1,  8,
#         3,  9,  4,  1,  3, 10,  4,  5, 14,  2, 13, 14,  2,  0,  4, 10,  2,
#        11,  9,  2,  2,  2,  4,  4,  8,  8,  5,  9,  9, 13,  3, 14,  0,  1,
#        13,  7,  3,  8, 13,  1,  1,  7, 14,  4,  3,  1,  1, 13,  1, 10, 12,
#         1,  1,  2,  1,  8,  8, 14,  4, 11, 11,  4,  4, 12,  7, 13,  5,  8,
#        11,  3,  9,  4,  0, 11, 10, 11,  0, 12,  3,  0,  4,  2, 11, 14,  4,
#         6,  2, 12,  3,  2,  2,  1,  1,  2,  2, 11,  9, 11, 13,  9, 14,  9,
#         4,  5,  4,  2,  2, 11,  2,  3,  1,  3, 10, 14,  0,  3,  4,  3,  5,
#         4, 13, 12, 13, 13,  1,  9,  1, 12,  4,  2,  1, 10,  0])

# %%
# Смотрим распределение данных по кластерам
sns.histplot(data = {"Kmeans_classters": kmeans_prediction}, 
             kde=True)
plt.show()

# %%
fig = plt.figure(figsize=(30, 15))
ax = fig.add_subplot()
ax.scatter(tsne_clusters_number[:, 0], tsne_clusters_number[:, 1], cmap=plt.cm.Spectral, c=kmeans.labels_, marker='o', cmap='rainbow')
# ax.set_title("%s: (%.2g sec)" % (label, t1 - t0))
ax.axis('tight')
plt.show()

# %% [markdown]
# Как мы видим многие точки находятся довольно далеко от своих кластеров, попробуем другое разбиение

# %% [markdown]
# ### Вывод
# Если полагаться на визуальный анализ, то 9 класстеров является наилучшим результатом
# Выбросы из класетров имеются, но их единицы

# %% [markdown]
# ## На основании вышеполученной информации, разобьем данные на 9 класстеров

# %%
kmeans = KMeans(
    n_clusters=9, # На сколько кластеров поделить наш ДС
    init='random', # Начальная инициализация центров кластеров
    n_init=10, # Начальное колиечтво этих точек (центров класстеров)
    max_iter=300, # 
    tol=1e-04 # Величина изменения при сдвиге
)
kmeans_prediction = kmeans.fit_predict(df)

# %%
# Смотрим распределение данных по кластерам
sns.histplot(data = {"Kmeans_classters": kmeans_prediction}, 
             kde=True)
plt.show()

# %%
fig = plt.figure(figsize=(30, 15))
ax = fig.add_subplot()
ax.scatter(tsne_clusters_number[:, 0], tsne_clusters_number[:, 1], c=kmeans.labels_, marker='o', cmap='rainbow')
# ax.set_title("%s: (%.2g sec)" % (label, t1 - t0))
ax.axis('tight')
plt.show()

# %% [markdown]
# # Обучим классификатор "дерево решений" и посмотрим по каким параметрам определяется класс
